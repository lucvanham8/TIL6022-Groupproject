# %% [markdown]
# ## TIL6022
#
# This report will explore the impact of the COVID-19 pandemic on the usage on diferent modes of transport, the recovery in the years after, and a forecast of transport use in the future years.
#
# This is a project made by:
#
# - Koen Schmoutziguer 5260760
# - Oscar de Boer
# - Luc van Ham
# - Martijn Hofwegen 5857600
# - Floris Nieuwenhuyse 5333032
#
# The repository contains:
#
# - report: Contains the whole research process, with images of the graphs. There is no code in this document.
# - Codes for graphs used in report: Contains the codes used for making the graphs.
# - Forecasting: contains the forecast models for 2030.
#
# ## Contribution Statement
#
# - Koen Schmoutziguer:
# - Oscar de Boer:
# - Luc van Ham:
# - Martijn Hofwegen:
# - Floris Nieuwenhuyse:
