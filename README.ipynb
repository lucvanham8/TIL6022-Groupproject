# %% [markdown]
# ## TIL6022
# This is a project made by:
#
# - Koen Schmoutziguer 5260760
# - Oscar de Boer 5640067
# - Luc van Ham 5375614
# - Martijn Hofwegen 5857600
# - Floris Nieuwenhuyse 5333032
#
# The repository contains:
#
# "report": Contains the whole research process, with images of the graphs. There is no code in this document.
#
# "Codes for graphs used in report": Contains the codes used for making the graphs.
#
# "forecasting_models" contains the code for the two forecasted models and the graphs that show the results
#
# ## Contribution Statement
#
# - Koen Schmoutziguer: writing report and adding figures and tables in the markdown cell, helping teammates with github problems,
# - Oscar de Boer: Coding for the forecast model and answering RQ 1 and 2
# - Luc van Ham: Help code for the forecast model and answering RQ 4
# - Martijn Hofwegen: Writing text, coding for question 3, clearing up the repository.
# - Floris Nieuwenhuyse: Writing introduction, analyzing models, clarifying code, discussion
