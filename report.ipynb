# %% [markdown]
# # The Recovery of Transport Performance After COVID-19
#
# ### Group members
# <div style="font-size: 12px;">
#
# |        Name       |   #   |
# |-------------------|-------|
# |Koen Schmoutziguer |5260760|
# |Oscar de Boer      |5640067|
# |Floris Nieuwenhuyse|5333032|
# |Luc van Ham        |5375615|
# |Martijn Hofwegen   |5857600|
#
# </div>
#
# ## 1. Introduction
# In the last few months of 2019, the COVID-19 pandemic caused the entire world to adapt. Due to the virus, meetings and lectures were hosted online, and people were not allowed to go to offices. The use of public transport and motorways dropped accordingly.
#
# This report will explore the impact of the COVID-19 pandemic on the usage of these modes of transport, the recovery in the years after, and a forecast of transport use in the future years.
#
# ### 1.1 Objectives
# The main objective of this study is to analyze how the performance of different transport modes in the Netherlands was affected by the COVID-19 pandemic and how they have recovered since. The study aims to provide insights into:
# - The relative impact of COVID-19 on different modes of passenger transport (car, local public transport (bus, tram, metro), trains, bicycle, and walking).
# - Regional variations in recovery between urban and rural areas.
# - Regional variations in recovery per province
# - Forecasting future transport performance and identifying when levels are expected to return to pre-COVID (2019) levels.
#
# #### 1.2  Data pipeline
# - Importing data from the CBS CSV files
# - Structuring and organizing relevant data
# - Creating line plots that show the trends
# - Creating a plot for travel data of the Netherlands for regional differences
# - Comparing data for the province and the city/rural environment.
# - Creating a forecast for the future
# - Assesign reliability and evaluating results of the model
#
# #### 1.3 Data Sources
# CBS Open data StatLine – Totale vervoersprestatie in Nederland; vervoerwijzen, regio’s
# 	https://opendata.cbs.nl/statline/#/CBS/nl/dataset/84687NED/table?ts=1759138063
#
# The CBS dataset 84687NED – Transport Performance in the Netherlands provides annual figures on the total number of kilometers traveled within the Netherlands, broken down by transport mode (car, public transport, bicycle, freight/other) and by region (provinces and degree of urbanization). The data, collected through the ODiN survey, covers residents aged six and older. In our study, we will use this dataset to compare transport performance across modes before, during, and after COVID-19 with 2019 as a baseline, to assess regional differences between urban and rural areas and to examine recovery trends over time in order to forecast developments up to 2030.
#
# CBS Mobiliteit; per persoon, persoonskenmerken, motieven en regio’s (woon-werk verkeer)
# https://opendata.cbs.nl/statline/#/CBS/nl/dataset/84713NED/table
#
# The CBS dataset 84713NED – Mobility by person, personal characteristics, motives and regions provides detailed data on individual mobility behavior in the Netherlands, including the number of trips, distances, transport modes, motives (such as commuting, shopping, leisure), and breakdowns by personal and regional characteristics. In our study we will focus especially on home-work (commuting) travel data: how many trips or kilometers are made for commuting, what transport modes are used, and how this varies across regions and over time.
#
# #### 1.4 Geographical Scale
# By keeping the scope within the Netherlands it is possible to compare the transportation data for the different regions in the Netherlands. Because the different regions often largely differ in the amount of urban and rural areas it is possible to research if urban or rural areas could better cope with the impacts of COVID-19 on the various transportation modes.
# - National coverage: Netherlands.
# - Subdivisions: Comparison across regions and between urban and rural areas.
#
# #### 1.5 Temporal Scale
# The data from the two datasets is from 2018 to 2023. This then includes the data in the years before COVID-19 where the values can be used to describe the “normal” transportation levels before the pandemic. It also includes the years during the pandemic, which show how the transportation levels were affected by COVID-19. Lastly, it includes the years in which the transportation levels slowly returned back to “normal”.
# - Early data: 2018-2019
# - Main COVID-19 impact years: 2020–2022.
# - Recovery analysis: 2023–2024.
# - Forecast horizon: 2025–2030.
#
# ## 2. Research Questions
# Main question:\
# How were different transport mode performances affected, did they recover after COVID-19 and how was the recovery process?
#
# Sub-questions:
# - How did the transport performance of different modes of transport change during and after the corona period (2020–2022) compared to 2019?
# - Which transport modes show the largest recovery compared to pre-COVID levels?
# - Are there significant differences in the degree of recovery between urban and rural regions in the Netherlands?
# - Are there significant differences in the degree of recovery between provinces in the Netherlands?
# - Based on historical trends, how is transport performance likely to develop over the next five years (2025–2030), and if or when will each mode of transport return to pre-COVID levels?
#
# ## 3. Answering the research questions
# #### 3.1 How did the transport performance of different modes of transport change during and after the corona period (2020-2022) compared to 2019?
# As seen in figure 1 the transport performance of the various transport modes experienced a significant dip between 2019 and 2020. This was due to the emergency policies and regulations introduced by the Dutch government to suppress the spread of COVID-19 in the Netherlands. Because of the policies most people had to work from home and it was not allowed to visit family and friends. After the corona period, transport performance started to recover again as more and more people returned back to normal everyday life. The total transport performance however never fully recovered to the values before COVID-19 indicating that some people never returned to their original schedule.
#
# <div style="text-align: center;">
#   <img src="Graphs/Performance%20of%20transport%20modes%202018-2023.png" width="800"><br>
#   <em>Figure 1: Performance of transport modes between 2018 and 2023.</em>
# </div>
#
# #### 3.2 Which transport modes show the largest recovery compared to pre-COVID levels?
# In contrast to figure 1, figure 2 shows the relative change in transport performance per travel mode. Figure 2 shows clearly that every transport mode experienced a decrease in performance except for walking. This is because walking became a popular activity for people during the corona period to still go outside and have some form of exercise. It was also an activity for people to break the long days of only staying inside their own homes.
#
# <div style="text-align: center;">
#   <img src="Graphs/Recovery of transport modes.png" width="800"><br>
#   <em>Figure 2: Recovery of the performance of transport modes.</em>
# </div>
#
# #### 3.3 Are there significant differences in the degree of recovery between urban and rural regions in the Netherlands?
# Both graphs show that travel performance dropped sharply in 2020 due to COVID-19 and then slowly recovered between 2021 and 2023. Figure 3 shows similar patterns for all urbanisation levels, but highly urbanised areas recovered a bit faster.
#
# For Figure 4, the categories were grouped as follows:
# “Extremely urbanised,” “Strongly urbanised,” and “Moderately urbanised” were combined into Urban, while “Hardly urbanised” and “Not urbanised” were combined into Rural.
#
# Figure 4 confirms this: urban areas show slightly higher recovery levels than rural areas after 2020. The difference is small, so the recovery trend is mostly the same across the country.
#
# To awnser the question:
#
# Urban regions recovered a bit quicker than rural ones, but the overall recovery pattern in the Netherlands is very similar for all regions.
#
# <div style="text-align: center;">
#   <img src="Graphs/Degrees of urbanization.png" width="800"><br>
#   <em>Figure 3: Recovery by degree of urbanization.</em>
# </div>
#   <div style="text-align: center;">
#   <img src="Graphs/Degrees of urbanization grouped.png" width="800"><br>
#   <em>Figure 4: Recovery by degree of urbanization grouped.</em>
# </div>
#
# #### 3.4 Are there significant differences in the degree of recovery between provinces in the Netherlands?
# Based on the recovery index generated for question 3.3, differences in recovery per province can be determined. As seen in Figure 5, there are significant differences between provinces. However, there is no visible division between rural and urban provinces.
#
# <div style="text-align: center;">
#   <img src="Graphs/Recovery per province.png" width="800"><br>
#   <em>Figure 5: Recovery of the transport performance per province.</em>
# </div>
#
# In Groningen and Fryslan, changes in relative total travel recovered the weakest, ranging only from 80 to 85 percent. Drenthe ranges between 95 to 100 percent. Even though the total recovery for these urbanisation degrees differ from eachother, there is no noticable pattern when comparing the provinces individually.
#
# To answer the question: In this chart, there are indeed significant differences in the degree of recovery between provinces, but there is no visible pattern based on the degree of urbanisation in these provinces.
#
# #### 3.5 Based on historical trends, how is transport performance likely to develop over the next five years (2025–2030), and if or when will each mode of transport return to pre-COVID levels?
#
# HIER MOET NOG DE INTRO VOOR DE FORECAST MODEL
#
# ##### Results
#
# <div style="text-align: center;">
#   <img src="Graphs/forecast mobility trend.png" width="800"><br>
#   <em>Figure 6: Recovery of the transport performance per province.</em>
# </div>
#
# <div style="text-align: center;">
#   <img src="Graphs/Forecast total travel.png" width="800"><br>
#   <em>Figure 7: Recovery of the transport performance per province.</em>
# </div>
#
# Figure 6 and 7 show the results of the forecast models. These figures will be discussed and assessed for accuracy using the following method.
# The two forecast models are evaluated using the cross-validation and performance metric functions of Prophet. The cross-validation function simulates the past. It repeatedly trains the model on the historical data and then looks at how well it predicts. The performance metric function takes this output and calculates performance statistics. To assess the accuracy of the model, we look at the Mean Absolute Percentage Error (MAPE). This metric shows the average forecast error as a percentage of the actual value.
#
# The results of the first model, shown in Figure 6, show very strange behaviour in the forecast, which is not anywhere near what would be expected. The figure shows an immediate drop and then very high spikes.
# The accuracy of the model is questionable. All but one of the MAPE values are low. These are below a statistically significant p-value of 0.05. The first run, however, shows a much higher maps value. This is most likely due to a very large spike or outlier in the data, which in this model is the years where we see the COVID-19 effect. This means that the model works well for forecasting based on the pre-COVID period (1999-2019). When considering the COVID period of 2020-2023, the model is not able to make accurate forecasts anymore. Hence, the forecast of the total travel kilometres shows strange results. This cannot be interpreted as trustworthy.
#
# The evaluation of Model 2, results shown in Figure 7, shows a forecast where the total travel kilometres are increasing. This is somewhat in line with the expectation that travel behaviour is gradually recovering in the next few years. It is, however, recovering and increasing very rapidly, faster than expected.
# The blue area in the figure shows the error margins. This is a very broad range. The result of the evaluation of this model shows a MAPE value of 0.67. This means that the error margin is 67% of the forecasted value. This is very high and does mean that these results are essentially not usable because it is not accurate enough. The reason for this is clear: there is not enough data in this model to accurately forecast the future
#
# The conclusion of the fifth sub-question is that the data and methods used in this study can not be used to accurately forecast the recovery. The two models rely on too little data, and the Prophet model can in this situation not handle the COVID events in a trustworthy way.
# A recommendation is to further research using the current data, if it is possible to fit better forecasting models using Prophet. A better recommendation would be to expand on the data used.
#
# ## 4. Conclusion
# After looking into five sub-questions the information to answer the main research question has been acquired. First of all, after plotting the data for the transport performance of each mode it is clear that almost every transport mode experienced a massive decrease in total kilometers travelled due to the pandemic. The only mode that didn’t experience a decrease but an increase in kilometers travelled was walking. This can be explained with the fact that most people had to work from home during the pandemic causing a massive decrease in work related travel. The pandemic also made it harder to practice sports as distance between individuals had to be maintained and inside sport areas were closed, which caused people to go on daily walks for exercise and leisure.
#
# Secondly figure 2 shows that public transport in the form of trains, buses, trams and metros have taken the longest time to recover. Public transport also took the biggest hit in transport performance because PT companies faced big challenges on how to transport passengers while complying to all COVID-19 regulations.
#
# Lastly the recovery process started off slow as it took people a while to get into the normal course of events after the pandemic. Per province there are significant differences in the recovery process indicating that geographic differences have an impact on how the transport performances recovered after COVID-19.
#
# The results for the forecasting model are not reliable enough to form a conclusion. Based on the results we would expect that the recovery happens in 2024 or 2025 with the exemption of public transport modes.
#
# ## 5. Discussion
